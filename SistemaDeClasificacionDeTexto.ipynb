# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from bs4 import BeautifulSoup
import urllib.request

# Configura una solicitud con un encabezado User-Agent para imitar un navegador
url = 'https://librefinanciero.com'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}
request = urllib.request.Request(url, headers=headers)

# Abre la URL y parsea el contenido
response = urllib.request.urlopen(request)
html = response.read()
soup = BeautifulSoup(html, "html5lib")
text = soup.get_text(strip=True)
print(text)
# Out:
# 🥇Alcanza la Libertad Financiera y Retírate🥇 - 【Libre Financiero】{"@context":"https://schema.org","@graph":[{"@type":"WebPage","@id":"https://librefinanciero.com/","url":"https://librefinanciero.com/","name":"🥇Alcanza la Libertad Financiera y Retírate🥇 - 【Libre Financiero】","isPartOf":{"@id":"https://librefinanciero.com/#website"},"about":{"@id":"https://librefinanciero.com/#/schema/person/eac2ac957f89526d68f1baa1de35a76b"},"primaryImageOfPage":{"@id":"https://librefinanciero.com/#primaryimage"},"image":{"@id":"https://librefinanciero.com/#primaryimage"},"thumbnailUrl":"https://librefinanciero.com/wp-content/uploads/2019/04/Cabecera-v3-jpg-1024x311.jpg","datePublished":"2019-03-29T20:59:50+00:00","dateModified":"2020-09-10T09:08:31+00:00","description":"¿Quieres alcanzar la Libertad Financiera y tener la vida que deseas? ⇨ Sí que se puede y en este blog encontrarás las respuestas✅","breadcrumb":{"@id":"https://librefinanciero.com/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{
# ...

# %% [markdown]
# **Tokenizar Texto**

# %%
# Creo los Tokens por palabras
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text,'spanish')
tokens = [word.lower() for word in tokens if word.isalpha()] # remueve los signos de puntuacion
print(tokens)
# Out:
# ['la', 'libertad', 'financiera', 'y', 'context', 'https', 'graph', 'type', 'webpage', 'id', 'https', 'url', 'https', 'name', 'la', 'libertad', 'financiera', 'y', 'ispartof', 'id', 'https', 'website', 'about', 'id', 'https', 'primaryimageofpage', 'id', 'https', 'primaryimage', 'image', 'id', 'https', 'primaryimage', 'thumbnailurl', 'https', 'datepublished', 'datemodified', 'description', 'alcanzar', 'la', 'libertad', 'financiera', 'y', 'tener', 'la', 'vida', 'que', 'deseas', 'sí', 'que', 'se', 'puede', 'y', 'en', 'este', 'blog', 'encontrarás', 'las', 'breadcrumb', 'id', 'https', 'breadcrumb', 'inlanguage', 'potentialaction', 'type', 'readaction', 'target', 'https', 'type', 'imageobject', 'inlanguage', 'id', 'https', 'primaryimage', 'url', 'https', 'contenturl', 'https', 'type', 'breadcrumblist', 'id', 'https', 'breadcrumb', 'itemlistelement', 'type', 'listitem', 'position', 'name', 'home', 'type', 'website', 'id', 'https', 'website', 'url', 'https', 'name', 'financiero', 'alcanza', 'l
# ...

# %%
# Verifico frecuencia de palabras
freq = nltk.FreqDist(tokens)
for key,val in freq.items():
    print(str(key) + ':' + str(val))
# Out:
# la:509
# libertad:79
# financiera:94
# y:305
# context:1
# https:38
# graph:1
# type:12
# webpage:1
# id:15
# url:9
# name:5
# ispartof:1
# website:3
# about:1
# primaryimageofpage:1
# primaryimage:3
# image:2
# thumbnailurl:1
# datepublished:1
# datemodified:1
# description:2
# alcanzar:44
# tener:46
# vida:34
# que:734
# deseas:2
# sí:29
# se:92
# puede:23
# en:526
# este:128
# blog:17
# encontrarás:3
# las:115
# breadcrumb:3
# inlanguage:4
# potentialaction:2
# readaction:1
# target:2
# imageobject:2
# contenturl:2
# breadcrumblist:1
# itemlistelement:1
# listitem:1
# position:3
# home:3
# financiero:15
# alcanza:3
# independencia:29
# publisher:1
# searchaction:1
# entrypoint:1
# urltemplate:1
# required:1
# person:1
# organization:1
# width:5
# height:2
# caption:1
# logo:1
# cdata:8
# baseurl:1
# ext:1
# svgurl:1
# svgext:1
# source:1
# concatemoji:1
# this:43
# file:10
# is:6
# function:24
# i:9
# n:12
# var:74
# o:60
# s:6
# e:42
# c:6
# try:4
# supporttests:1
# timestamp:1
# ...

# %%
# Visualizo Tokens
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
freq.plot(30,cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# **Stop Word**

# %%
from nltk.corpus import stopwords
clean_tokens = tokens[:]

for token in tokens:

    if token in stopwords.words('spanish'):
        clean_tokens.remove(token)
print(clean_tokens)
# Out:
# ['libertad', 'financiera', 'context', 'https', 'graph', 'type', 'webpage', 'id', 'https', 'url', 'https', 'name', 'libertad', 'financiera', 'ispartof', 'id', 'https', 'website', 'about', 'id', 'https', 'primaryimageofpage', 'id', 'https', 'primaryimage', 'image', 'id', 'https', 'primaryimage', 'thumbnailurl', 'https', 'datepublished', 'datemodified', 'description', 'alcanzar', 'libertad', 'financiera', 'tener', 'vida', 'deseas', 'puede', 'blog', 'encontrarás', 'breadcrumb', 'id', 'https', 'breadcrumb', 'inlanguage', 'potentialaction', 'type', 'readaction', 'target', 'https', 'type', 'imageobject', 'inlanguage', 'id', 'https', 'primaryimage', 'url', 'https', 'contenturl', 'https', 'type', 'breadcrumblist', 'id', 'https', 'breadcrumb', 'itemlistelement', 'type', 'listitem', 'position', 'name', 'home', 'type', 'website', 'id', 'https', 'website', 'url', 'https', 'name', 'financiero', 'alcanza', 'independencia', 'description', 'publisher', 'id', 'https', 'potentialaction', 'type', 'searc
# ...

# %%
# Verfico nuevamente frecuencia de palabras
freq_clean = nltk.FreqDist(clean_tokens)
for key,val in freq_clean.items():
    print(str(key) + ':' + str(val))
# Out:
# libertad:79
# financiera:94
# context:1
# https:38
# graph:1
# type:12
# webpage:1
# id:15
# url:9
# name:5
# ispartof:1
# website:3
# about:1
# primaryimageofpage:1
# primaryimage:3
# image:2
# thumbnailurl:1
# datepublished:1
# datemodified:1
# description:2
# alcanzar:44
# tener:46
# vida:34
# deseas:2
# puede:23
# blog:17
# encontrarás:3
# breadcrumb:3
# inlanguage:4
# potentialaction:2
# readaction:1
# target:2
# imageobject:2
# contenturl:2
# breadcrumblist:1
# itemlistelement:1
# listitem:1
# position:3
# home:3
# financiero:15
# alcanza:3
# independencia:29
# publisher:1
# searchaction:1
# entrypoint:1
# urltemplate:1
# required:1
# person:1
# organization:1
# width:5
# height:2
# caption:1
# logo:1
# cdata:8
# baseurl:1
# ext:1
# svgurl:1
# svgext:1
# source:1
# concatemoji:1
# this:43
# file:10
# is:6
# function:24
# i:9
# n:12
# var:74
# s:6
# c:6
# try:4
# supporttests:1
# timestamp:1
# new:5
# date:3
# t:21
# catch:3
# p:3
# return:11
# u:3
# switch:1
# case:2
# flag:3
# ...

# %%
# Visualizo Tokens nuevamente
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
freq_clean.plot(30,cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet
synonyms = []
for syn in wordnet.synsets('investment'):
    for lemma in syn.lemmas():
        synonyms.append(lemma.name())
print(synonyms)
# Out:
# ['investing', 'investment', 'investment', 'investment_funds', 'investment', 'investment', 'investment', 'investment', 'investiture']

# %% [markdown]
# **Obtener Sinónimos**

# %%
# Reemplazo tokens sinónimos
for ind,si in enumerate(synonyms):
  clean_tokens_sin = [word.replace(synonyms[ind],'investment') for word in clean_tokens]

# %%
# Reemplazar Tokens sinónimos manual
sinonimos = ['libertad', 'independencia']

for ind,si in enumerate(sinonimos):
  clean_tokens_sin = [word.replace(sinonimos[ind],'libertad') for word in clean_tokens]

# %%
# Recalculo frecuencia de palabras con sinónimos agregados
#freq_clean_sin
fleq_clean_sin = nltk.FreqDist(clean_tokens_sin)
for key,val in fleq_clean_sin.items():
    print(str(key) + ':' + str(val))
# Out:
# libertad:108
# financiera:94
# context:1
# https:38
# graph:1
# type:12
# webpage:1
# id:15
# url:9
# name:5
# ispartof:1
# website:3
# about:1
# primaryimageofpage:1
# primaryimage:3
# image:2
# thumbnailurl:1
# datepublished:1
# datemodified:1
# description:2
# alcanzar:44
# tener:46
# vida:34
# deseas:2
# puede:23
# blog:17
# encontrarás:3
# breadcrumb:3
# inlanguage:4
# potentialaction:2
# readaction:1
# target:2
# imageobject:2
# contenturl:2
# breadcrumblist:1
# itemlistelement:1
# listitem:1
# position:3
# home:3
# financiero:15
# alcanza:3
# publisher:1
# searchaction:1
# entrypoint:1
# urltemplate:1
# required:1
# person:1
# organization:1
# width:5
# height:2
# caption:1
# logo:1
# cdata:8
# baseurl:1
# ext:1
# svgurl:1
# svgext:1
# source:1
# concatemoji:1
# this:43
# file:10
# is:6
# function:24
# i:9
# n:12
# var:74
# s:6
# c:6
# try:4
# supporttests:1
# timestamp:1
# new:5
# date:3
# t:21
# catch:3
# p:3
# return:11
# u:3
# switch:1
# case:2
# flag:3
# emoji:2
# f:1
# ...

# %%
# Visualización Tokens
fleq_clean_sin.plot(30, cumulative = False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# **Obtener Sinónimos**

# %%
from nltk.corpus import wordnet
anonyms = []
for syn in wordnet.synsets('good'):
    for l in syn.lemmas():
      if l.antonyms():
        anonyms.append(l.antonyms()[0].name())
print(anonyms)
# Out:
# ['evil', 'evilness', 'bad', 'badness', 'bad', 'evil', 'ill']

# %% [markdown]
# **Derivación Regresiva**

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
print(stemmer.stem('eating'))
# Out:
# eat

# %%
# Derivación regresiva textos en español

from nltk.stem import SnowballStemmer

spanish_stemmer = SnowballStemmer('spanish')
print(spanish_stemmer.stem('trabajando'))
print(spanish_stemmer.stem('trabajando'))
# Out:
# trabaj
# trabaj

# %%
clean_tokens_sin_stem = [spanish_stemmer.stem(token) for token in clean_tokens_sin]

# %%
clean_tokens_sin_stem
# Out:
# ['libert',
#  'financ',
#  'context',
#  'https',
#  'graph',
#  'type',
#  'webpag',
#  'id',
#  'https',
#  'url',
#  'https',
#  'nam',
#  'libert',
#  'financ',
#  'ispartof',
#  'id',
#  'https',
#  'websit',
#  'about',
#  'id',
#  'https',
#  'primaryimageofpag',
#  'id',
#  'https',
#  'primaryimag',
#  'imag',
#  'id',
#  'https',
#  'primaryimag',
#  'thumbnailurl',
#  'https',
#  'datepublish',
#  'datemodifi',
#  'description',
#  'alcanz',
#  'libert',
#  'financ',
#  'ten',
#  'vid',
#  'des',
#  'pued',
#  'blog',
#  'encontr',
#  'breadcrumb',
#  'id',
#  'https',
#  'breadcrumb',
#  'inlanguag',
#  'potentialaction',
#  'type',
#  'readaction',
#  'target',
#  'https',
#  'type',
#  'imageobject',
#  'inlanguag',
#  'id',
#  'https',
#  'primaryimag',
#  'url',
#  'https',
#  'contenturl',
#  'https',
#  'type',
#  'breadcrumblist',
#  'id',
#  'https',
#  'breadcrumb',
#  'itemlistelement',
#  'type',
#  'listitem',
#  'position',
#  'nam',
#  'hom',
#  'type',
# ...

# %%
# Recalculo frecuencia de palabras con sinónimos agregados
fleq_clean_sin_stems = nltk.FreqDist(clean_tokens_sin_stem)
for key,val in fleq_clean_sin_stems.items():
    print(str(key) + ':' + str(val))
# Out:
# libert:108
# financ:98
# context:1
# https:38
# graph:1
# type:12
# webpag:1
# id:15
# url:9
# nam:5
# ispartof:1
# websit:3
# about:1
# primaryimageofpag:1
# primaryimag:3
# imag:2
# thumbnailurl:1
# datepublish:1
# datemodifi:1
# description:2
# alcanz:62
# ten:49
# vid:34
# des:5
# pued:99
# blog:17
# encontr:7
# breadcrumb:3
# inlanguag:4
# potentialaction:2
# readaction:1
# target:2
# imageobject:2
# contenturl:2
# breadcrumblist:1
# itemlistelement:1
# listitem:1
# position:3
# hom:3
# financier:31
# publish:1
# searchaction:1
# entrypoint:1
# urltemplat:1
# requir:1
# person:35
# organization:1
# width:5
# height:2
# caption:1
# log:1
# cdat:8
# baseurl:1
# ext:1
# svgurl:1
# svgext:1
# sourc:1
# concatemoji:1
# this:43
# fil:12
# is:6
# function:24
# i:9
# n:12
# var:74
# s:6
# c:6
# try:4
# supporttests:1
# timestamp:1
# new:5
# dat:15
# t:21
# catch:3
# p:3
# return:11
# u:3
# switch:1
# cas:39
# flag:3
# emoji:2
# f:1
# undefin:6
# workerglobalscop:2
# self:1
# ...

# %%
# Visualizo Tokens
fleq_clean_sin_stems.plot(30, cumulative = False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>
